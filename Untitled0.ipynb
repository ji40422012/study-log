# %% [markdown]
# <a href="https://colab.research.google.com/github/ji40422012/study-log/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#'안녕하세요'10번 출력하기
print("안녕하세요")
print("안녕하세요")
print("안녕하세요")
print("안녕하세요")
print("안녕하세요")
print("안녕하세요")
print("안녕하세요")
print("안녕하세요")
print("안녕하세요")
print("안녕하세요")
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %%
print("안녕하세요안녕하세요")
# Out:
# 안녕하세요안녕하세요

# %%
print("안녕하세요""안녕하세요")
# Out:
# 안녕하세요안녕하세요

# %%
#'안녕하세요'10번 출력하기
print("안녕하세요"*10)
print("안녕하세요\n"*10)
# Out:
# 안녕하세요안녕하세요안녕하세요안녕하세요안녕하세요안녕하세요안녕하세요안녕하세요안녕하세요안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %%
print('안녕하세요1')
print('안녕하세요4')
print('안녕하세요2')
print('안녕하세요3')
print('안녕하세요5')
# Out:
# 안녕하세요1
# 안녕하세요4
# 안녕하세요2
# 안녕하세요3
# 안녕하세요5

# %% [markdown]
# ```
# # 코드로 형식 지정됨
# ```

# %%
print('안녕하세요\n'*5)
print('안녕\n하세요'*5) #어딜 기준으로 줄바꿈을 할지-\n은 줄바꿈 역할
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
#
# 안녕
# 하세요안녕
# 하세요안녕
# 하세요안녕
# 하세요안녕
# 하세요

# %%
print('안녕\n하\n세요'*5)
# Out:
# 안녕
# 하
# 세요안녕
# 하
# 세요안녕
# 하
# 세요안녕
# 하
# 세요안녕
# 하
# 세요

# %%
import keyword
print(keyword.kwlist)
print(f"총 키워드 개수: {len(keyword.kwlist)}")
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# 총 키워드 개수: 35
